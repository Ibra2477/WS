# %%
from pprint import pprint
import querif
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 from pprint import pprint
# ----> 2 import querif
#
# File ~/Developer/WS/querif/__init__.py:2
#       1 from .execute import execute_query
# ----> 2 from .llm.llm import query_with_llm
#       3 import querif.llm as llm
#       4 import querif.const as const
#
# File ~/Developer/WS/querif/llm/__init__.py:1
# ----> 1 from .llm import *
#       2 from .prompts import *
#
# File ~/Developer/WS/querif/llm/llm.py:10
#       8 from ..const import prefixes
#       9 from ..execute import execute_query
# ---> 10 from .prompts import (
#      11     query_type_detection_prompt,
#      12     target_class_detection_prompt,
#      13     fact_lookup_prompt,
#      14     aggregation_prompt,
#      15     comparison_prompt,
#      16     class_query_prompt,
#      17     boolean_prompt,
#      18     superlative_prompt,
#      19 )
#      20 import warnings
#      23 class QueryType(Enum):
#
# ImportError: cannot import name 'comparison_prompt' from 'querif.llm.prompts' (/Users/grisha/Developer/WS/querif/llm/prompts.py)

# %%
pprint(querif.const.list_queries())
print()
pprint(querif.const.list_templates())

# %%
# desc, query = querif.const.get_predefined_query("Barack_Obama")
# print(desc)
# print(query)

# %%
# results = utils.execute_query(query)
# pprint(results)

# %%
# utils.plot_clusters(utils.cluster_embeddings_KMeans(results))

# %%
# desc, query = utils.get_parametrized_query(t_label="Artist_Albums", pr_labels='dbpedia', artist_name="Adele", limit=5)
# print(desc)
# print(query)

# %%
# results = utils.execute_query(query)
# pprint(results)

# %%
# query = utils.llm.create_query("List the capitals of all countries in Europe.", config_key="DEEPSEEK")
# print(query, "\n")
# results = utils.execute_query(query)
# pprint(results)

# %%
prompt  = "List the capitals of all countries in Europe with number of citizens greater than 20 million."
print(querif.query_with_llm(prompt))
