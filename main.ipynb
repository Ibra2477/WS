# %%
from pprint import pprint
import utils

# %%
desc, query = utils.get_predefined_query("Barack_Obama")
print(desc)
print(query)
# Out:
# Get labels of Barack Obama
#
# PREFIX dbr:  <http://dbpedia.org/resource/>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX dbo:  <http://dbpedia.org/ontology/>
# SELECT ?object WHERE {dbr:Barack_Obama rdfs:label ?object.}

# %%
from utils.pipeline import pipeline_complet


results = utils.execute_query(query)
pprint(results)

pipeline_complet(query, api="dbpedia")
# Out:
# {'head': {'link': [], 'vars': ['object']},
#  'results': {'bindings': [{'object': {'type': 'literal',
#                                       'value': 'Barack Obama',
#                                       'xml:lang': 'en'}},
#                           {'object': {'type': 'literal',
#                                       'value': 'باراك أوباما',
#                                       'xml:lang': 'ar'}},
#                           {'object': {'type': 'literal',
#                                       'value': 'Barack Obama',
#                                       'xml:lang': 'ca'}},
#                           {'object': {'type': 'literal',
#                                       'value': 'Μπαράκ Ομπάμα',
#                                       'xml:lang': 'el'}},
#                           {'object': {'type': 'literal',
#                                       'value': 'Barack Obama',
#                                       'xml:lang': 'cs'}},
# ...

# %%
desc, query = utils.get_parametrized_query(t_label="Artist_Albums", artist_name="Adele", limit=5)
print(desc)
print(query)
# Out:
# Get N most recent albums of a specified artist with release dates
#
# PREFIX dbr:  <http://dbpedia.org/resource/>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX dbo:  <http://dbpedia.org/ontology/>
#
# SELECT DISTINCT ?album_label ?release_date WHERE {
#     ?artist rdfs:label "Adele"@en .
#     ?album dbo:artist ?artist ;
#             rdfs:label ?album_label ;
#             dbo:releaseDate ?release_date .
#     FILTER (lang(?album_label) = "en")
# }
# ORDER BY DESC(?release_date)
# LIMIT 5

# %%
results = utils.execute_query(query)
pprint(results)
# Out:
# {'head': {'link': [], 'vars': ['album_label', 'release_date']},
#  'results': {'bindings': [{'album_label': {'type': 'literal',
#                                            'value': 'Oh My God (Adele song)',
#                                            'xml:lang': 'en'},
#                            'release_date': {'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#                                             'type': 'literal',
#                                             'value': '2021-11-29'}},
#                           {'album_label': {'type': 'literal',
#                                            'value': 'Can I Get It',
#                                            'xml:lang': 'en'},
#                            'release_date': {'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#                                             'type': 'literal',
#                                             'value': '2021-11-19'}},
# ...

# %%
from utils.pipeline import pipeline_complet


df_final = pipeline_complet(query, api="dbpedia")
# Out:
# Exécution de la requête sur dbpedia...
# Analyse sémantique et génération du graphique...
# c:\Users\ImmGe\miniconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning:
#
# KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
