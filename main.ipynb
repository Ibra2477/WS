# %%
from pprint import pprint
import importlib
import utils
importlib.reload(utils)
# Out:
# <module 'utils' from '/Users/mohamadoweidat/WS/utils/__init__.py'>

# %%
desc, query = utils.get_predefined_query("Barack_Obama", pr_labels='dbpedia')
print(desc)
print(query)
# Out:
# Get labels of Barack Obama
#
# PREFIX dbr:  <http://dbpedia.org/resource/>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX dbo:  <http://dbpedia.org/ontology/>
# PREFIX dbp: <http://dbpedia.org/property/>
#
# SELECT ?object WHERE {dbr:Barack_Obama rdfs:label ?object.}

# %%
desc, query = utils.get_predefined_query("Drake_songs_and_writers", pr_labels='dbpedia')
print(desc)
print(query)
# Out:
# Get songs by Drake with their writers
#
# PREFIX dbr:  <http://dbpedia.org/resource/>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX dbo:  <http://dbpedia.org/ontology/>
# PREFIX dbp: <http://dbpedia.org/property/>
#
# SELECT ?song ?songLabel (GROUP_CONCAT(DISTINCT ?writerLabel; separator=" | ") AS ?writers)
#         WHERE {
#             { <http://dbpedia.org/resource/Drake_(musician)> ^dbo:artist ?song . }
#             UNION
#             { <http://dbpedia.org/resource/Drake_(musician)> ^dbp:artist ?song . }
#
#             { ?song dbo:writer ?writer . }
#             UNION
#             { ?song dbp:writer ?writer . }
#
#             ?song rdfs:label ?songLabel .
#             ?writer rdfs:label ?writerLabel .
#
#             FILTER(lang(?songLabel) = "en")
#             FILTER(lang(?writerLabel) = "en")
#         }
#         GROUP BY ?song ?songLabel
#         LIMIT 100

# %%
results = utils.execute_query(query)
pprint(results)
# Out:
# {'head': {'link': [], 'vars': ['song', 'songLabel', 'writers']},
#  'results': {'bindings': [{'song': {'type': 'uri',
#                                     'value': 'http://dbpedia.org/resource/Knife_Talk'},
#                            'songLabel': {'type': 'literal',
#                                          'value': 'Knife Talk',
#                                          'xml:lang': 'en'},
#                            'writers': {'type': 'literal',
#                                        'value': '21 Savage | ASAP Rocky | '
#                                                 'Drake (musician) | G Koop | '
#                                                 'Juicy J | Metro Boomin | '
#                                                 'Project Pat'}},
#                           {'song': {'type': 'uri',
#                                     'value': 'http://dbpedia.org/resource/Portland_(song)'},
#                            'songLabel': {'type': 'literal',
# ...

# %%
desc, query = utils.get_predefined_query("Recent_Albums_2010_plus", pr_labels='dbpedia')
print(desc)
print(query)
# Out:
# Get recent albums released after 2010
#
# PREFIX dbr:  <http://dbpedia.org/resource/>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX dbo:  <http://dbpedia.org/ontology/>
# PREFIX dbp: <http://dbpedia.org/property/>
#
# SELECT DISTINCT ?album ?albumName ?Artist ?genre ?date ?title
#         WHERE {
#             ?album a dbo:Album .
#             ?album rdfs:label ?albumName .
#             ?album dbo:artist ?Artist .
#             OPTIONAL {
#                 ?album dbo:genre ?genre .
#                 ?album dbo:releaseDate ?date .
#                 ?album dbp:title ?title .
#             }
#             FILTER (
#                 lang(?albumName) = "en" &&
#                 (!bound(?date) || ?date >= "2010-01-01"^^xsd:date)
#             )
#         }
#         LIMIT 100

# %%
results = utils.execute_query(query)
pprint(results)
# Out:
# {'head': {'link': [],
#           'vars': ['album', 'albumName', 'Artist', 'genre', 'date', 'title']},
#  'results': {'bindings': [{'Artist': {'type': 'uri',
#                                       'value': 'http://dbpedia.org/resource/Nathanael_Saleh'},
#                            'album': {'type': 'uri',
#                                      'value': 'http://dbpedia.org/resource/The_Place_Where_Lost_Things_Go'},
#                            'albumName': {'type': 'literal',
#                                          'value': 'The Place Where Lost Things '
#                                                   'Go',
#                                          'xml:lang': 'en'},
#                            'date': {'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#                                     'type': 'literal',
#                                     'value': '2018-11-26'},
#                            'genre': {'type': 'uri',
# ...

# %%
desc, query = utils.get_predefined_query("Music_Genres", pr_labels='dbpedia')
print(desc)
print(query)
# Out:
# Get genres and names of songs
#
# PREFIX dbr:  <http://dbpedia.org/resource/>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX dbo:  <http://dbpedia.org/ontology/>
# PREFIX dbp: <http://dbpedia.org/property/>
#
# SELECT DISTINCT ?songName ?genreLabel
#         WHERE {
#             ?song a dbo:Song .
#             ?song rdfs:label ?songName .
#             OPTIONAL { ?song dbo:genre ?genre .
#             ?genre rdfs:label ?genreLabel.  }
#             FILTER(lang(?songName) = "en")
#         }
#         LIMIT 100

# %%
results = utils.execute_query(query)
pprint(results)
# Out:
# {'head': {'link': [], 'vars': ['songName', 'genreLabel']},
#  'results': {'bindings': [{'genreLabel': {'type': 'literal',
#                                           'value': 'English folk music',
#                                           'xml:lang': 'en'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Cold Blow and the Rainy '
#                                                  'Night (song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Urbano music',
#                                           'xml:lang': 'en'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Lagunas (song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
# ...

# %%
desc, query = utils.get_predefined_query("Non_US_Artists_And_Songs", pr_labels='dbpedia')
print(desc)
print(query)
# Out:
# Get non-US artists and their songs
#
# PREFIX dbr:  <http://dbpedia.org/resource/>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX dbo:  <http://dbpedia.org/ontology/>
# PREFIX dbp: <http://dbpedia.org/property/>
#
# SELECT DISTINCT ?artist ?artistName ?song ?songName ?country
#         WHERE {
#             ?song a dbo:Song .
#             ?song rdfs:label ?songName .
#             ?song dbo:artist ?artist .
#
#             ?artist a dbo:MusicalArtist .
#             ?artist rdfs:label ?artistName .
#
#             OPTIONAL { ?artist dbo:nationality ?country . }
#             OPTIONAL { ?artist dbp:nationality ?country . }
#
#             FILTER (
#                 lang(?songName) = "en" &&
#                 lang(?artistName) = "en" &&
#                 bound(?country) &&
#                 ?country != dbr:United_States
#             )
#         }
#         LIMIT 100

# %%
results = utils.execute_query(query)
pprint(results)
# Out:
# {'head': {'link': [],
#           'vars': ['artist', 'artistName', 'song', 'songName', 'country']},
#  'results': {'bindings': [{'artist': {'type': 'uri',
#                                       'value': "http://dbpedia.org/resource/D'Prince"},
#                            'artistName': {'type': 'literal',
#                                           'value': "D'Prince",
#                                           'xml:lang': 'en'},
#                            'country': {'type': 'uri',
#                                        'value': 'http://dbpedia.org/resource/Nigerians'},
#                            'song': {'type': 'uri',
#                                     'value': 'http://dbpedia.org/resource/Dorobucci'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Dorobucci',
#                                         'xml:lang': 'en'}},
#                           {'artist': {'type': 'uri',
# ...

# %%
utils.plot_clusters(utils.cluster_embeddings_KMeans(results))

# %%
desc, query = utils.get_parametrized_query(t_label="Artist_Albums", pr_labels='dbpedia', artist_name="Adele", limit=5)
print(desc)
print(query)
# Out:
# Get N most recent albums of a specified artist with release dates
#
# PREFIX dbr:  <http://dbpedia.org/resource/>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX dbo:  <http://dbpedia.org/ontology/>
# PREFIX dbp: <http://dbpedia.org/property/>
#
#
# SELECT DISTINCT ?album_label ?release_date WHERE {
#     ?artist rdfs:label "Adele"@en .
#     ?album dbo:artist ?artist ;
#             rdfs:label ?album_label ;
#             dbo:releaseDate ?release_date .
#     FILTER (lang(?album_label) = "en")
# }
# ORDER BY DESC(?release_date)
# LIMIT 5

# %%
results = utils.execute_query(query)
pprint(results)
# Out:
# {'head': {'link': [], 'vars': ['album_label', 'release_date']},
#  'results': {'bindings': [{'album_label': {'type': 'literal',
#                                            'value': 'Oh My God (Adele song)',
#                                            'xml:lang': 'en'},
#                            'release_date': {'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#                                             'type': 'literal',
#                                             'value': '2021-11-29'}},
#                           {'album_label': {'type': 'literal',
#                                            'value': 'My Little Love',
#                                            'xml:lang': 'en'},
#                            'release_date': {'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#                                             'type': 'literal',
#                                             'value': '2021-11-19'}},
# ...

# %%
# Out:
# Get songs of a specified genre with their artists
#
# PREFIX dbr:  <http://dbpedia.org/resource/>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX dbo:  <http://dbpedia.org/ontology/>
# PREFIX dbp: <http://dbpedia.org/property/>
#
#
# SELECT DISTINCT ?song_label ?artist_label WHERE {
#     ?song a dbo:Song ;
#           rdfs:label ?song_label ;
#           dbo:genre dbr:Música_urbana ;
#           dbo:artist ?artist .
#     ?artist rdfs:label ?artist_label .
#     FILTER (lang(?song_label) = "en")
#     FILTER (lang(?artist_label) = "en")
# }
# LIMIT 5

# %%
# Out:
# {'head': {'link': [], 'vars': ['song_label', 'artist_label']},
#  'results': {'bindings': [], 'distinct': False, 'ordered': True}}

# %%
query = utils.llm.create_query("List the capitals of all countries in Europe.", config_key="DEEPSEEK")
print(query, "\n")
results = utils.execute_query(query)
pprint(results)
# Out:
# PREFIX dbo: <http://dbpedia.org/ontology/>
# PREFIX dbr: <http://dbpedia.org/resource/>
#
# SELECT ?country ?capital
# WHERE {
#   ?country a dbo:Country .
#   ?country dbo:capital ?capital .
#   ?country dbo:location dbr:Europe .
# }
#
# {'head': {'link': [], 'vars': ['country', 'capital']},
#  'results': {'bindings': [], 'distinct': False, 'ordered': True}}

# %%
prompt  = "List the capitals of all countries in Europe with number of citizens greater than 20 million."
pprint(utils.llm.parse_prompt(prompt))
pprint(utils.llm.link_entities(prompt))
# Out:
# {'comparators': ['>'],
#  'nouns': ['the capitals', 'all countries', 'Europe', 'number', 'citizens'],
#  'numbers': ['greater than 20 million']}
# {'@confidence': '0.5',
#  '@policy': 'whitelist',
#  '@sparql': '',
#  '@support': '0',
#  '@text': 'List the capitals of all countries in Europe with number of '
#           'citizens greater than 20 million.',
#  '@types': '',
#  'Resources': [{'@URI': 'http://dbpedia.org/resource/Europe',
#                 '@offset': '38',
#                 '@percentageOfSecondRank': '0.0018414304748817039',
#                 '@similarityScore': '0.9981260548047736',
#                 '@support': '81911',
#                 '@surfaceForm': 'Europe',
#                 '@types': 'Schema:Place,Schema:Continent,DBpedia:PopulatedPlace,DBpedia:Place,DBpedia:Location,DBpedia:Continent'}]}

# %%
# Test de l'analyse de graphe avec Drake
desc, query = utils.get_predefined_query("Drake_songs_and_writers", pr_labels='dbpedia')
drake_results = utils.execute_query(query)

# %%
# Recharger le module pour les nouvelles fonctions
importlib.reload(utils)

# Analyse complète avec les bonnes clés
G, metrics, fig = utils.analyze_graph(drake_results, 'songLabel', 'writers', 'Drake Collaboration Network')
fig.show()
# Out:
# Nombre de nœuds: 188
# Nombre d'arêtes: 100
#
# Top 5 par degré:
#   Drake (musician): 11
#   Drake (musician) | PartyNextDoor: 2
#   40 (music producer) | 40 (record producer) | Boi-1da | Cardo (music producer) | Cardo (record producer) | Drake (musician): 2
#   Knife Talk: 1
#   21 Savage | ASAP Rocky | Drake (musician) | G Koop | Juicy J | Metro Boomin | Project Pat: 1
#
# Top 5 PageRank:
#   Drake (musician): 0.0298
#   Drake (musician) | PartyNextDoor: 0.0078
#   40 (music producer) | 40 (record producer) | Boi-1da | Cardo (music producer) | Cardo (record producer) | Drake (musician): 0.0078
#   Knife Talk: 0.0053
#   21 Savage | ASAP Rocky | Drake (musician) | G Koop | Juicy J | Metro Boomin | Project Pat: 0.0053
