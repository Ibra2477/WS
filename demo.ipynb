# %%
from pprint import pprint
import querif

# %%
pprint(querif.const.list_queries())
print()
pprint(querif.const.list_templates())
# Out:
# ['Barack_Obama',
#  'Michael_Jackson_songs',
#  'Recent_Albums_2010_plus',
#  'Music_Genres',
#  'Non_US_Artists_And_Songs']
#
# ['Artist_Albums', 'Artist_Singles', 'Artist_Genres', 'Artist_Birth_Info']

# %%
desc, query = querif.const.get_query("Music_Genres")
print(desc)
print(query)
# Out:
# Get genres and names of songs
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
# PREFIX dbr: <http://dbpedia.org/resource/>
# PREFIX dbo: <http://dbpedia.org/ontology/>
# PREFIX dbp: <http://dbpedia.org/property/>
# PREFIX dbc: <http://dbpedia.org/resource/Category:>
# PREFIX dbt: <http://dbpedia.org/resource/Template:>
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# PREFIX dc: <http://purl.org/dc/elements/1.1/>
# PREFIX dcterms: <http://purl.org/dc/terms/>
# PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
# PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
# PREFIX georss: <http://www.georss.org/georss/>
# PREFIX prov: <http://www.w3.org/ns/prov#>
# PREFIX wikidata: <http://www.wikidata.org/entity/>
# PREFIX schema: <http://schema.org/>
#
#
# SELECT DISTINCT ?songName ?genreLabel
# WHERE {
#     ?song a dbo:Song .
#     ?song rdfs:label ?songName .
#     OPTIONAL { ?song dbo:genre ?genre .
#     ?genre rdfs:label ?genreLabel.  }
#     FILTER(lang(?songName) = "en")
# }
# LIMIT 100

# %%
results = querif.execute_query(query)
pprint(results)
# Out:
# {'head': {'link': [], 'vars': ['songName', 'genreLabel']},
#  'results': {'bindings': [{'genreLabel': {'type': 'literal',
#                                           'value': 'English folk music',
#                                           'xml:lang': 'en'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Cold Blow and the Rainy '
#                                                  'Night (song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Urbano music',
#                                           'xml:lang': 'en'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Lagunas (song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Música urbana',
#                                           'xml:lang': 'es'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Lagunas (song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Dark culture',
#                                           'xml:lang': 'en'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Blue Moon Rising (song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Schwarze Szene',
#                                           'xml:lang': 'de'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Blue Moon Rising (song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Schwarze Szene',
#                                           'xml:lang': 'pt'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Blue Moon Rising (song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Тёмная сцена',
#                                           'xml:lang': 'ru'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Blue Moon Rising (song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Темна сцена',
#                                           'xml:lang': 'uk'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Blue Moon Rising (song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'en'},
#                            'songName': {'type': 'literal',
#                                         'value': '2:30',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afro-fusion',
#                                           'xml:lang': 'ca'},
#                            'songName': {'type': 'literal',
#                                         'value': '2:30',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'fr'},
#                            'songName': {'type': 'literal',
#                                         'value': '2:30',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'pt'},
#                            'songName': {'type': 'literal',
#                                         'value': '2:30',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'sv'},
#                            'songName': {'type': 'literal',
#                                         'value': '2:30',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'en'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Big FU',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afro-fusion',
#                                           'xml:lang': 'ca'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Big FU',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'fr'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Big FU',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'pt'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Big FU',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'sv'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Big FU',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'en'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Buga (song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afro-fusion',
#                                           'xml:lang': 'ca'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Buga (song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'fr'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Buga (song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'pt'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Buga (song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'sv'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Buga (song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'en'},
#                            'songName': {'type': 'literal',
#                                         'value': 'City Boys',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afro-fusion',
#                                           'xml:lang': 'ca'},
#                            'songName': {'type': 'literal',
#                                         'value': 'City Boys',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'fr'},
#                            'songName': {'type': 'literal',
#                                         'value': 'City Boys',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'pt'},
#                            'songName': {'type': 'literal',
#                                         'value': 'City Boys',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'sv'},
#                            'songName': {'type': 'literal',
#                                         'value': 'City Boys',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'en'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Gwagwalada (song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afro-fusion',
#                                           'xml:lang': 'ca'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Gwagwalada (song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'fr'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Gwagwalada (song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'pt'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Gwagwalada (song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'sv'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Gwagwalada (song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'en'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Nightmares (Chris Brown '
#                                                  'song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afro-fusion',
#                                           'xml:lang': 'ca'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Nightmares (Chris Brown '
#                                                  'song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'fr'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Nightmares (Chris Brown '
#                                                  'song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'pt'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Nightmares (Chris Brown '
#                                                  'song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'sv'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Nightmares (Chris Brown '
#                                                  'song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'en'},
#                            'songName': {'type': 'literal',
#                                         'value': 'RTID (Rich Till I Die)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afro-fusion',
#                                           'xml:lang': 'ca'},
#                            'songName': {'type': 'literal',
#                                         'value': 'RTID (Rich Till I Die)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'fr'},
#                            'songName': {'type': 'literal',
#                                         'value': 'RTID (Rich Till I Die)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'pt'},
#                            'songName': {'type': 'literal',
#                                         'value': 'RTID (Rich Till I Die)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'sv'},
#                            'songName': {'type': 'literal',
#                                         'value': 'RTID (Rich Till I Die)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'en'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Sensational (song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afro-fusion',
#                                           'xml:lang': 'ca'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Sensational (song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'fr'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Sensational (song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'pt'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Sensational (song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Afrobeats',
#                                           'xml:lang': 'sv'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Sensational (song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Mariachi',
#                                           'xml:lang': 'en'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Aparentemente Bien',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'مارياتشي',
#                                           'xml:lang': 'ar'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Aparentemente Bien',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Mariachi',
#                                           'xml:lang': 'cs'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Aparentemente Bien',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Mariatxi',
#                                           'xml:lang': 'ca'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Aparentemente Bien',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Μαριάτσι',
#                                           'xml:lang': 'el'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Aparentemente Bien',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Mariaĉo',
#                                           'xml:lang': 'eo'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Aparentemente Bien',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Mariachi',
#                                           'xml:lang': 'de'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Aparentemente Bien',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Mariatxi',
#                                           'xml:lang': 'eu'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Aparentemente Bien',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Mariachi',
#                                           'xml:lang': 'fr'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Aparentemente Bien',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Mariachi',
#                                           'xml:lang': 'es'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Aparentemente Bien',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'マリアッチ',
#                                           'xml:lang': 'ja'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Aparentemente Bien',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': '마리아치',
#                                           'xml:lang': 'ko'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Aparentemente Bien',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Mariachi',
#                                           'xml:lang': 'it'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Aparentemente Bien',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Mariachi',
#                                           'xml:lang': 'nl'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Aparentemente Bien',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Mariachi',
#                                           'xml:lang': 'pt'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Aparentemente Bien',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Mariachi',
#                                           'xml:lang': 'pl'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Aparentemente Bien',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Мариачи',
#                                           'xml:lang': 'ru'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Aparentemente Bien',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Mariachi',
#                                           'xml:lang': 'sv'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Aparentemente Bien',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Маріачі',
#                                           'xml:lang': 'uk'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Aparentemente Bien',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': '墨西哥街頭樂隊',
#                                           'xml:lang': 'zh'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Aparentemente Bien',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Mariachi',
#                                           'xml:lang': 'en'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Por el Contrario',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'مارياتشي',
#                                           'xml:lang': 'ar'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Por el Contrario',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Mariachi',
#                                           'xml:lang': 'cs'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Por el Contrario',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Mariatxi',
#                                           'xml:lang': 'ca'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Por el Contrario',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Μαριάτσι',
#                                           'xml:lang': 'el'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Por el Contrario',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Mariaĉo',
#                                           'xml:lang': 'eo'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Por el Contrario',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Mariachi',
#                                           'xml:lang': 'de'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Por el Contrario',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Mariatxi',
#                                           'xml:lang': 'eu'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Por el Contrario',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Mariachi',
#                                           'xml:lang': 'fr'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Por el Contrario',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Mariachi',
#                                           'xml:lang': 'es'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Por el Contrario',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'マリアッチ',
#                                           'xml:lang': 'ja'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Por el Contrario',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': '마리아치',
#                                           'xml:lang': 'ko'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Por el Contrario',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Mariachi',
#                                           'xml:lang': 'it'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Por el Contrario',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Mariachi',
#                                           'xml:lang': 'nl'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Por el Contrario',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Mariachi',
#                                           'xml:lang': 'pt'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Por el Contrario',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Mariachi',
#                                           'xml:lang': 'pl'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Por el Contrario',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Мариачи',
#                                           'xml:lang': 'ru'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Por el Contrario',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Mariachi',
#                                           'xml:lang': 'sv'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Por el Contrario',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Маріачі',
#                                           'xml:lang': 'uk'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Por el Contrario',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': '墨西哥街頭樂隊',
#                                           'xml:lang': 'zh'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Por el Contrario',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Music of the Philippines',
#                                           'xml:lang': 'en'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Binibini',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Musique philippine',
#                                           'xml:lang': 'fr'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Binibini',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Disco-pop',
#                                           'xml:lang': 'en'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Not My Fault (song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Styles of pop music',
#                                           'xml:lang': 'en'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Not My Fault (song)',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Acoustic music',
#                                           'xml:lang': 'en'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Nothing Like Us',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Akustická hudba',
#                                           'xml:lang': 'cs'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Nothing Like Us',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Música acústica',
#                                           'xml:lang': 'ca'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Nothing Like Us',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Akustikversion',
#                                           'xml:lang': 'de'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Nothing Like Us',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Musika akustiko',
#                                           'xml:lang': 'eu'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Nothing Like Us',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Musique acoustique',
#                                           'xml:lang': 'fr'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Nothing Like Us',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Música acústica',
#                                           'xml:lang': 'es'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Nothing Like Us',
#                                         'xml:lang': 'en'}},
#                           {'genreLabel': {'type': 'literal',
#                                           'value': 'Musik akustik',
#                                           'xml:lang': 'in'},
#                            'songName': {'type': 'literal',
#                                         'value': 'Nothing Like Us',
#                                         'xml:lang': 'en'}}],
#              'distinct': False,
#              'ordered': True}}

# %%
querif.analyze.plot_clusters(querif.analyze.semantic_cluster_dbpedia(results))
# Out:
# /Users/grisha/Developer/WS/.venv/lib/python3.13/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /Users/grisha/Developer/WS/.venv/lib/python3.13/site-packages/umap/spectral.py:548: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(

# %%
# Utilisation des templates paramétrés
desc, query = querif.const.get_template("Artist_Albums", artist_name="Adele", limit=10)
print(desc)
print(query)
# Out:
# Get N most recent albums of a specified artist with release dates
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
# PREFIX dbr: <http://dbpedia.org/resource/>
# PREFIX dbo: <http://dbpedia.org/ontology/>
# PREFIX dbp: <http://dbpedia.org/property/>
# PREFIX dbc: <http://dbpedia.org/resource/Category:>
# PREFIX dbt: <http://dbpedia.org/resource/Template:>
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# PREFIX dc: <http://purl.org/dc/elements/1.1/>
# PREFIX dcterms: <http://purl.org/dc/terms/>
# PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
# PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
# PREFIX georss: <http://www.georss.org/georss/>
# PREFIX prov: <http://www.w3.org/ns/prov#>
# PREFIX wikidata: <http://www.wikidata.org/entity/>
# PREFIX schema: <http://schema.org/>
#
#
# SELECT DISTINCT ?album_label ?release_date WHERE {
#     ?artist rdfs:label "Adele"@en .
#     ?album dbo:artist ?artist ;
#             rdfs:label ?album_label ;
#             dbo:releaseDate ?release_date .
#     FILTER (lang(?album_label) = "en")
# }
# ORDER BY DESC(?release_date)
# LIMIT 10

# %%
results = querif.execute_query(query)
pprint(results)
# Out:
# {'head': {'link': [], 'vars': ['album_label', 'release_date']},
#  'results': {'bindings': [{'album_label': {'type': 'literal',
#                                            'value': 'Oh My God (Adele song)',
#                                            'xml:lang': 'en'},
#                            'release_date': {'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#                                             'type': 'literal',
#                                             'value': '2021-11-29'}},
#                           {'album_label': {'type': 'literal',
#                                            'value': 'My Little Love',
#                                            'xml:lang': 'en'},
#                            'release_date': {'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#                                             'type': 'literal',
#                                             'value': '2021-11-19'}},
#                           {'album_label': {'type': 'literal',
#                                            'value': 'To Be Loved (Adele song)',
#                                            'xml:lang': 'en'},
#                            'release_date': {'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#                                             'type': 'literal',
#                                             'value': '2021-11-19'}},
#                           {'album_label': {'type': 'literal',
#                                            'value': 'Can I Get It',
#                                            'xml:lang': 'en'},
#                            'release_date': {'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#                                             'type': 'literal',
#                                             'value': '2021-11-19'}},
#                           {'album_label': {'type': 'literal',
#                                            'value': 'Easy on Me',
#                                            'xml:lang': 'en'},
#                            'release_date': {'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#                                             'type': 'literal',
#                                             'value': '2021-10-15'}},
#                           {'album_label': {'type': 'literal',
#                                            'value': 'Water Under the Bridge',
#                                            'xml:lang': 'en'},
#                            'release_date': {'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#                                             'type': 'literal',
#                                             'value': '2016-11-14'}},
#                           {'album_label': {'type': 'literal',
#                                            'value': 'Send My Love (To Your New '
#                                                     'Lover)',
#                                            'xml:lang': 'en'},
#                            'release_date': {'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#                                             'type': 'literal',
#                                             'value': '2016-05-16'}},
#                           {'album_label': {'type': 'literal',
#                                            'value': 'When We Were Young (Adele '
#                                                     'song)',
#                                            'xml:lang': 'en'},
#                            'release_date': {'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#                                             'type': 'literal',
#                                             'value': '2016-01-22'}},
#                           {'album_label': {'type': 'literal',
#                                            'value': 'Love in the Dark (song)',
#                                            'xml:lang': 'en'},
#                            'release_date': {'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#                                             'type': 'literal',
#                                             'value': '2015-11-20'}},
#                           {'album_label': {'type': 'literal',
#                                            'value': 'All I Ask',
#                                            'xml:lang': 'en'},
#                            'release_date': {'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#                                             'type': 'literal',
#                                             'value': '2015-11-20'}}],
#              'distinct': False,
#              'ordered': True}}

# %%
prompt = "what is DBpedia?"
query, results = querif.generate_and_execute_query(prompt, config_key="DEEPSEEK")
pprint(results)
# Out:
# Detected query type: DEFINITION
# {'head': {'link': [], 'vars': ['label', 'abstract', 'type']},
#  'results': {'bindings': [], 'distinct': False, 'ordered': True}}

# %%
prompt = "When was Michael Jackson born?"
query, results = querif.generate_and_execute_query(prompt, config_key="DEEPSEEK")
pprint(results)
# Out:
# Detected query type: FACT_LOOKUP
# {'head': {'link': [], 'vars': ['birthDate']},
#  'results': {'bindings': [{'birthDate': {'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#                                          'type': 'literal',
#                                          'value': '1958-08-29'}}],
#              'distinct': False,
#              'ordered': True}}

# %%
prompt = "Who is older between Taylor Swift and Katy Perry?"
query, results = querif.generate_and_execute_query(prompt, config_key="DEEPSEEK")
pprint(results)
# Out:
# Detected query type: COMPARISON
# {'head': {'link': [], 'vars': ['entity', 'label', 'birthDate']},
#  'results': {'bindings': [{'birthDate': {'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#                                          'type': 'literal',
#                                          'value': '1984-10-25'},
#                            'entity': {'type': 'uri',
#                                       'value': 'http://dbpedia.org/resource/Katy_Perry'},
#                            'label': {'type': 'literal',
#                                      'value': 'Katy Perry',
#                                      'xml:lang': 'en'}},
#                           {'birthDate': {'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#                                          'type': 'literal',
#                                          'value': '1989-12-13'},
#                            'entity': {'type': 'uri',
#                                       'value': 'http://dbpedia.org/resource/Taylor_Swift'},
#                            'label': {'type': 'literal',
#                                      'value': 'Taylor Swift',
#                                      'xml:lang': 'en'}}],
#              'distinct': False,
#              'ordered': True}}
