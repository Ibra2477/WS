# %%
from pprint import pprint
import querif

# %%
# pprint(querif.const.list_queries())
# print()
# pprint(querif.const.list_templates())

# %%
# desc, query = querif.const.get_query("Barack_Obama")
# print(desc)
# print(query)

# %%
# results = querif.execute_query(query)
# pprint(results)

# %%
# querif.analyze.plot_clusters(querif.analyze.cluster_embeddings_KMeans(results))

# %%
# desc, query = utils.get_parametrized_query(t_label="Artist_Albums", pr_labels='dbpedia', artist_name="Adele", limit=5)
# print(desc)
# print(query)

# %%
# results = utils.execute_query(query)
# pprint(results)

# %%
# query = utils.llm.create_query("List the capitals of all countries in Europe.", config_key="DEEPSEEK")
# print(query, "\n")
# results = utils.execute_query(query)
# pprint(results)

# %%
prompt = "When was Michael Jackson born?"
query, results = querif.generate_and_execute_query(prompt, config_key="DEEPSEEK")
print("Generated query:\n", query, "\n")
pprint(results)
# Out:
# Detected query type: FACT_LOOKUP
# Generated query:
#  PREFIX dbo: <http://dbpedia.org/ontology/>
# PREFIX dbr: <http://dbpedia.org/resource/>
#
# SELECT ?birthDate WHERE {
#     dbr:Michael_Jackson dbo:birthDate ?birthDate .
# }
#
# {'head': {'link': [], 'vars': ['birthDate']},
#  'results': {'bindings': [{'birthDate': {'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#                                          'type': 'literal',
#                                          'value': '1958-08-29'}}],
#              'distinct': False,
#              'ordered': True}}

# %%
prompt = "American musicians who won a Grammy award more than 15 times"
query, results = querif.generate_and_execute_query(prompt, config_key="DEEPSEEK")
print("Generated query:\n", query, "\n")
pprint(results)
# Out:
# Detected query type: CLASS_QUERY
# Entities: {'American': 'dbr:United_States', 'musicians': 'dbr:Musician', 'won': 'dbr:South_Korean_won', 'Grammy': 'dbr:Grammy_Awards', 'times': 'dbr:Cap_(sport)'}
# Target classes: ['dbo:Person']
# /Users/grisha/Developer/WS/querif/nl2sparql/utils.py:282: RuntimeWarning: Failed to verify properties for dbo:Person: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b"Virtuoso 37000 Error SP030: SPARQL compiler, line 22: syntax error at '/' before 'height'\n\nSPARQL query:\n#output-format:application/sparql-results+json\nPREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>\nPREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>\nPREFIX owl: <http://www.w3.org/2002/07/owl#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX dbr: <http://dbpedia.org/resource/>\nPREFIX dbo: <http://dbpedia.org/ontology/>\nPREFIX dbp: <http://dbpedia.org/property/>\nPREFIX dbc: <http://dbpedia.org/resource/Category:>\nPREFIX dbt: <http://dbpedia.org/resource/Template:>\nPREFIX foaf: <http://xmlns.com/foaf/0.1/>\nPREFIX dc: <http://purl.org/dc/elements/1.1/>\nPREFIX dcterms: <http://purl.org/dc/terms/>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>\nPREFIX georss: <http://www.georss.org/georss/>\nPREFIX prov: <http://www.w3.org/ns/prov#>\nPREFIX wikidata: <http://www.wikidata.org/entity/>\nPREFIX schema: <http://schema.org/>\n\n    SELECT DISTINCT ?property WHERE {\n        VALUES (?property) { (dbo:Person/height) (dbo:Person/weight) (dbo:activeYears) (dbo:allegiance) (dbo:birthName) (dbo:birthYear) (dbo:deathYear) (dbo:eyeColor) (dbo:hairColor) (dbo:pseudonym) (dbo:signature) (dbo:networth) (dbo:sex) (dbo:electionDate) (dbo:activeYearsEndDateMgr) (dbo:activeYearsEndYearMgr) (dbo:activeYearsStartDateMgr) (dbo:activeYearsStartYearMgr) (dbo:affair) (dbo:arrestDate) }\n        ?s rdf:type dbo:Person ;\n           ?property ?o .\n    }\n    \n"
#   warnings.warn(f"Failed to verify properties for {class_uri}: {e}", RuntimeWarning)
# Props of t. class {'data': ['dbo:Person/height', 'dbo:Person/weight', 'dbo:activeYears', 'dbo:allegiance', 'dbo:birthName', 'dbo:birthYear', 'dbo:deathYear', 'dbo:eyeColor', 'dbo:hairColor', 'dbo:pseudonym', 'dbo:signature', 'dbo:networth', 'dbo:sex', 'dbo:electionDate', 'dbo:activeYearsEndDateMgr', 'dbo:activeYearsEndYearMgr', 'dbo:activeYearsStartDateMgr', 'dbo:activeYearsStartYearMgr', 'dbo:affair', 'dbo:arrestDate'], 'object': ['dbo:agency', 'dbo:almaMater', 'dbo:board', 'dbo:careerStation', 'dbo:child', 'dbo:citizenship', 'dbo:college', 'dbo:deathCause', 'dbo:education', 'dbo:employer', 'dbo:militaryService', 'dbo:nationality', 'dbo:notableIdea', 'dbo:parent', 'dbo:partner', 'dbo:personFunction', 'dbo:philosophicalSchool', 'dbo:profession', 'dbo:relation', 'dbo:relative']}
# Generated query:
# PREFIX dbo: <http://dbpedia.org/ontology/>
# PREFIX dbr: <http://dbpedia.org/resource/>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX dbp: <http://dbpedia.org/property/>
#
# SELECT DISTINCT ?person ?label
# WHERE {
#     ?person a dbo:Person .
#     ?person rdfs:label ?label .
#     FILTER(lang(?label) = "en")
#
#     ?person dbo:nationality dbr:United_States .
#
#     ?person dbo:occupation ?occ .
#     ?occ a dbr:Musician .
#
#     ?person dbp:awards ?awards .
#     FILTER(CONTAINS(LCASE(?awards), "grammy"))
#
#     OPTIONAL {
#         ?person dbo:award ?awardList .
#         FILTER(CONTAINS(LCASE(?awardList), "grammy"))
#     }
# }
# LIMIT 100
# Generated query:
#  None
#
# None

# %%
prompt = "How many Albums did Drake release?"
query, results = querif.generate_and_execute_query(prompt, config_key="DEEPSEEK")
print("Generated query:\n", query, "\n")
pprint(results)
# Out:
# Detected query type: AGGREGATION
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/Developer/WS/.venv/lib/python3.13/site-packages/SPARQLWrapper/Wrapper.py:926, in SPARQLWrapper._query(self)
#     925 else:
# --> 926     response = urlopener(request)
#     927 return response, self.returnFormat
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:189, in urlopen(url, data, timeout, context)
#     188     opener = _opener
# --> 189 return opener.open(url, data, timeout)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:495, in OpenerDirector.open(self, fullurl, data, timeout)
#     494     meth = getattr(processor, meth_name)
# --> 495     response = meth(req, response)
#     497 return response
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:604, in HTTPErrorProcessor.http_response(self, request, response)
#     603 if not (200 <= code < 300):
# --> 604     response = self.parent.error(
#     605         'http', request, response, code, msg, hdrs)
#     607 return response
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:533, in OpenerDirector.error(self, proto, *args)
#     532 args = (dict, 'default', 'http_error_default') + orig_args
# --> 533 return self._call_chain(*args)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:466, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     465 func = getattr(handler, meth_name)
# --> 466 result = func(*args)
#     467 if result is not None:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:613, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     612 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 613     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 400: Bad Request
#
# During handling of the above exception, another exception occurred:
#
# QueryBadFormed                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 prompt = "How many Albums did Drake release?"
# ----> 2 query, results = querif.generate_and_execute_query(prompt, config_key="DEEPSEEK")
#       3 print("Generated query:\n", query, "\n")
#       4 pprint(results)
#
# File ~/Developer/WS/querif/nl2sparql/main.py:29, in generate_and_execute_query(prompt, config_key)
#      27 handler = handlers.get(query_type)
#      28 if handler:
# ---> 29     return handler(prompt, config_key)
#      31 return None, None
#
# File ~/Developer/WS/querif/nl2sparql/queries/aggregation.py:57, in generate_aggregation_query(prompt, config_key)
#      55 if entities:
#      56     main_entity = list(entities.values())[0]
# ---> 57     props = _get_entity_properties(main_entity, limit=20)
#      58     props_str = "\n".join([f"  {p['property']}" for p in props])
#      59 else:
#
# File ~/Developer/WS/querif/nl2sparql/utils.py:338, in _get_entity_properties(entity_uri, limit)
#     330 exclusion_filters = " && ".join([f'!STRSTARTS(STR(?property), "{uri}")' for uri in EXCLUDED_NAMESPACES])
#     332 query = f"""
#     333 SELECT DISTINCT ?property ?value WHERE {{
#     334     {entity_uri} ?property ?value .
#     335     FILTER({exclusion_filters})
#     336 }} LIMIT {limit}
#     337 """
# --> 338 results = execute_query(prefixes + query)
#     340 props = []
#     341 for r in results["results"]["bindings"]:
#
# File ~/Developer/WS/querif/execute.py:11, in execute_query(query)
#       9 sparql.setQuery(query)
#      10 sparql.setReturnFormat(JSON)
# ---> 11 results = sparql.query().convert()
#      12 return results
#
# File ~/Developer/WS/.venv/lib/python3.13/site-packages/SPARQLWrapper/Wrapper.py:960, in SPARQLWrapper.query(self)
#     942 def query(self) -> "QueryResult":
#     943     """
#     944     Execute the query.
#     945     Exceptions can be raised if either the URI is wrong or the HTTP sends back an error (this is also the
#    (...)    958     :rtype: :class:`QueryResult` instance
#     959     """
# --> 960     return QueryResult(self._query())
#
# File ~/Developer/WS/.venv/lib/python3.13/site-packages/SPARQLWrapper/Wrapper.py:930, in SPARQLWrapper._query(self)
#     928 except urllib.error.HTTPError as e:
#     929     if e.code == 400:
# --> 930         raise QueryBadFormed(e.read())
#     931     elif e.code == 404:
#     932         raise EndPointNotFound(e.read())
#
# QueryBadFormed: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'Virtuoso 37000 Error SP030: SPARQL compiler, line 22: syntax error at \'TV_series\' before \')\'\n\nSPARQL query:\n#output-format:application/sparql-results+json\nPREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>\nPREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>\nPREFIX owl: <http://www.w3.org/2002/07/owl#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX dbr: <http://dbpedia.org/resource/>\nPREFIX dbo: <http://dbpedia.org/ontology/>\nPREFIX dbp: <http://dbpedia.org/property/>\nPREFIX dbc: <http://dbpedia.org/resource/Category:>\nPREFIX dbt: <http://dbpedia.org/resource/Template:>\nPREFIX foaf: <http://xmlns.com/foaf/0.1/>\nPREFIX dc: <http://purl.org/dc/elements/1.1/>\nPREFIX dcterms: <http://purl.org/dc/terms/>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>\nPREFIX georss: <http://www.georss.org/georss/>\nPREFIX prov: <http://www.w3.org/ns/prov#>\nPREFIX wikidata: <http://www.wikidata.org/entity/>\nPREFIX schema: <http://schema.org/>\n\n    SELECT DISTINCT ?property ?value WHERE {\n        dbr:How_(TV_series) ?property ?value .\n        FILTER(!STRSTARTS(STR(?property), "http://www.w3.org/2002/07/owl#") && !STRSTARTS(STR(?property), "http://www.w3.org/ns/prov#") && !STRSTARTS(STR(?property), "http://dbpedia.org/resource/Template:") && !STRSTARTS(STR(?property), "http://www.wikidata.org/entity/") && !STRSTARTS(STR(?property), "http://purl.org/linguistics/gold/"))\n    } LIMIT 20\n    \n'

# %%
prompt = "Who is older between Taylor Swift and Katy Perry?"
query, results = querif.generate_and_execute_query(prompt, config_key="DEEPSEEK")
print("Generated query:\n", query, "\n")
pprint(results)
# Out:
# Detected query type: COMPARISON
# Generated query:
#  PREFIX dbo: <http://dbpedia.org/ontology/>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#
# SELECT ?entity ?label ?birthDate
# WHERE {
#   VALUES ?entity { dbr:Taylor_Swift dbr:Katy_Perry }
#   ?entity dbo:birthDate ?birthDate ;
#           rdfs:label ?label .
#   FILTER(lang(?label) = "en")
# }
# ORDER BY ?birthDate
#
# {'head': {'link': [], 'vars': ['entity', 'label', 'birthDate']},
#  'results': {'bindings': [{'birthDate': {'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#                                          'type': 'literal',
#                                          'value': '1984-10-25'},
#                            'entity': {'type': 'uri',
#                                       'value': 'http://dbpedia.org/resource/Katy_Perry'},
#                            'label': {'type': 'literal',
#                                      'value': 'Katy Perry',
#                                      'xml:lang': 'en'}},
#                           {'birthDate': {'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#                                          'type': 'literal',
#                                          'value': '1989-12-13'},
#                            'entity': {'type': 'uri',
#                                       'value': 'http://dbpedia.org/resource/Taylor_Swift'},
#                            'label': {'type': 'literal',
#                                      'value': 'Taylor Swift',
#                                      'xml:lang': 'en'}}],
#              'distinct': False,
#              'ordered': True}}

# %%
prompt = "What is jazz?"
query, results = querif.generate_and_execute_query(prompt, config_key="DEEPSEEK")
print("Generated query:\n", query, "\n")
pprint(results)
# Out:
# Detected query type: DEFINITION
# Generated query:
#
#     SELECT ?label ?abstract ?type WHERE {
#         dbr:String_theory rdfs:label ?label ;
#                       dbo:abstract ?abstract .
#         OPTIONAL { dbr:String_theory rdf:type ?type . }
#         FILTER (lang(?label) = "en" && lang(?abstract) = "en")
#     } LIMIT 1
#
#
# {'head': {'link': [], 'vars': ['label', 'abstract', 'type']},
#  'results': {'bindings': [], 'distinct': False, 'ordered': True}}

# %%
prompt = "How jazz and rap are related?"
query, results = querif.generate_and_execute_query(prompt, config_key="DEEPSEEK")
print("Generated query:\n", query, "\n")
pprint(results)
# Out:
# Detected query type: RELATIONSHIP
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/Developer/WS/.venv/lib/python3.13/site-packages/SPARQLWrapper/Wrapper.py:926, in SPARQLWrapper._query(self)
#     925 else:
# --> 926     response = urlopener(request)
#     927 return response, self.returnFormat
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:189, in urlopen(url, data, timeout, context)
#     188     opener = _opener
# --> 189 return opener.open(url, data, timeout)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:495, in OpenerDirector.open(self, fullurl, data, timeout)
#     494     meth = getattr(processor, meth_name)
# --> 495     response = meth(req, response)
#     497 return response
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:604, in HTTPErrorProcessor.http_response(self, request, response)
#     603 if not (200 <= code < 300):
# --> 604     response = self.parent.error(
#     605         'http', request, response, code, msg, hdrs)
#     607 return response
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:533, in OpenerDirector.error(self, proto, *args)
#     532 args = (dict, 'default', 'http_error_default') + orig_args
# --> 533 return self._call_chain(*args)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:466, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     465 func = getattr(handler, meth_name)
# --> 466 result = func(*args)
#     467 if result is not None:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:613, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     612 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 613     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 400: Bad Request
#
# During handling of the above exception, another exception occurred:
#
# QueryBadFormed                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 prompt = "How jazz and rap are related?"
# ----> 2 query, results = querif.generate_and_execute_query(prompt, config_key="DEEPSEEK")
#       3 print("Generated query:\n", query, "\n")
#       4 pprint(results)
#
# File ~/Developer/WS/querif/nl2sparql/main.py:29, in generate_and_execute_query(prompt, config_key)
#      27 handler = handlers.get(query_type)
#      28 if handler:
# ---> 29     return handler(prompt=prompt, config_key=config_key)
#      31 return None, None
#
# File ~/Developer/WS/querif/nl2sparql/queries/relationship.py:37, in generate_relationship_query(prompt, **other)
#      22 # Find direct relationships
#      23 query = f"""
#      24 SELECT ?predicate ?direction WHERE {{
#      25     {{
#    (...)     34 }}
#      35 """
# ---> 37 results = execute_query(prefixes + query)
#      38 return query, results
#
# File ~/Developer/WS/querif/execute.py:11, in execute_query(query)
#       9 sparql.setQuery(query)
#      10 sparql.setReturnFormat(JSON)
# ---> 11 results = sparql.query().convert()
#      12 return results
#
# File ~/Developer/WS/.venv/lib/python3.13/site-packages/SPARQLWrapper/Wrapper.py:960, in SPARQLWrapper.query(self)
#     942 def query(self) -> "QueryResult":
#     943     """
#     944     Execute the query.
#     945     Exceptions can be raised if either the URI is wrong or the HTTP sends back an error (this is also the
#    (...)    958     :rtype: :class:`QueryResult` instance
#     959     """
# --> 960     return QueryResult(self._query())
#
# File ~/Developer/WS/.venv/lib/python3.13/site-packages/SPARQLWrapper/Wrapper.py:930, in SPARQLWrapper._query(self)
#     928 except urllib.error.HTTPError as e:
#     929     if e.code == 400:
# --> 930         raise QueryBadFormed(e.read())
#     931     elif e.code == 404:
#     932         raise EndPointNotFound(e.read())
#
# QueryBadFormed: QueryBadFormed: A bad request has been sent to the endpoint: probably the SPARQL query is badly formed.
#
# Response:
# b'Virtuoso 37000 Error SP030: SPARQL compiler, line 23: syntax error at \'TV_series\' before \')\'\n\nSPARQL query:\n#output-format:application/sparql-results+json\nPREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>\nPREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>\nPREFIX owl: <http://www.w3.org/2002/07/owl#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX dbr: <http://dbpedia.org/resource/>\nPREFIX dbo: <http://dbpedia.org/ontology/>\nPREFIX dbp: <http://dbpedia.org/property/>\nPREFIX dbc: <http://dbpedia.org/resource/Category:>\nPREFIX dbt: <http://dbpedia.org/resource/Template:>\nPREFIX foaf: <http://xmlns.com/foaf/0.1/>\nPREFIX dc: <http://purl.org/dc/elements/1.1/>\nPREFIX dcterms: <http://purl.org/dc/terms/>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>\nPREFIX georss: <http://www.georss.org/georss/>\nPREFIX prov: <http://www.w3.org/ns/prov#>\nPREFIX wikidata: <http://www.wikidata.org/entity/>\nPREFIX schema: <http://schema.org/>\n\n    SELECT ?predicate ?direction WHERE {\n        {\n            dbr:How_(TV_series) ?predicate dbr:Jazz .\n            BIND("forward" AS ?direction)\n        }\n        UNION\n        {\n            dbr:Jazz ?predicate dbr:How_(TV_series) .\n            BIND("reverse" AS ?direction)\n        }\n    }\n    \n'

# %%
prompt = "Most listened french songs"
query, results = querif.generate_and_execute_query(prompt, config_key="DEEPSEEK")
print("Generated query:\n", query, "\n")
pprint(results)
# Out:
# Detected query type: SUPERLATIVE
# Generated query:
#  PREFIX dbo: <http://dbpedia.org/ontology/>
# PREFIX dct: <http://purl.org/dc/terms/>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#
# SELECT ?song ?title ?listens
# WHERE {
#   ?song a dbo:Song ;
#         dct:subject ?category ;
#         rdfs:label ?title ;
#         dbo:streams ?listens .
#   FILTER(LANG(?title) = 'en')
#   ?category rdfs:label "French songs"@en .
# }
# ORDER BY DESC(?listens)
# LIMIT 1
#
# {'head': {'link': [], 'vars': ['song', 'title', 'listens']},
#  'results': {'bindings': [], 'distinct': False, 'ordered': True}}

# %%
prompt = "Is stromae french?"
query, results = querif.generate_and_execute_query(prompt, config_key="DEEPSEEK")
print("Generated query:\n", query, "\n")
pprint(results)
# Out:
# Detected query type: BOOLEAN
# Generated query:
#  ASK {
#   dbr:Stromae dbo:nationality dbr:France .
# }
#
# {'boolean': False, 'head': {'link': []}}
